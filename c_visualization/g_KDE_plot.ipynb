# %% [markdown]
# ## 커널 밀도 추정(Kernel Density Estimation, KDE) plot

# %%
# !pip install seaborn==0.9.0
# Out:
# Requirement already satisfied: seaborn==0.9.0 in c:\python310\lib\site-packages (0.9.0)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\python310\lib\site-packages (from seaborn==0.9.0) (3.8.4)
# Requirement already satisfied: numpy>=1.9.3 in c:\python310\lib\site-packages (from seaborn==0.9.0) (1.26.4)
# Requirement already satisfied: pandas>=0.15.2 in c:\python310\lib\site-packages (from seaborn==0.9.0) (2.2.1)
# Requirement already satisfied: scipy>=0.14.0 in c:\python310\lib\site-packages (from seaborn==0.9.0) (1.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python310\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python310\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (24.0)
# Requirement already satisfied: pillow>=8 in c:\python310\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python310\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas>=0.15.2->seaborn==0.9.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python310\lib\site-packages (from pandas>=0.15.2->seaborn==0.9.0) (2024.1)
# Requirement already satisfied: six in c:\python310\lib\site-packages (from cycler>=0.10->matplotlib>=1.4.3->seaborn==0.9.0) (1.12.0)
# WARNING: Ignoring invalid distribution -otebook (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -otebook (c:\python310\lib\site-packages)

# %%
import pandas as pd
import seaborn as sns

# %%
body_df = pd.read_csv('data/body.csv', index_col=0)
body_df
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0
# ...        ...     ...
# 996      171.8    68.2
# 997      171.5    75.6
# 998      177.9    66.5
# 999      174.4    72.0
# 1000     173.5    77.4
#
# [1000 rows x 2 columns]

# %%
body_df['Height'].value_counts().sort_index()
# Out:
# Height
# 154.4    1
# 155.5    1
# 157.4    1
# 157.8    1
# 158.0    1
#         ..
# 190.3    1
# 191.2    1
# 191.8    1
# 192.4    1
# 193.1    1
# Name: count, Length: 262, dtype: int64

# %%
body_df['Height'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='Height'>

# %%
# bw: 추측을 어느 정도 수준으로 할지 설정
sns.kdeplot(body_df['Height'], bw=0.5)
# Out:
# <Axes: >
